# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("readcsvfile").getOrCreate()
df3 = spark.read.csv("Products.csv",header=True,inferSchema=True)
df3.show()
# Out:
# +----------+----------+----------+-------------+--------------------+-----------+---------+-------------+--------+----------------+
# | OrderDate|InvoiceNum|ProductKey|      Country|  EnglishProductName|SalesAmount|UnitPrice|OrderQuantity|  TaxAmt|TotalProductCost|
# +----------+----------+----------+-------------+--------------------+-----------+---------+-------------+--------+----------------+
# |01-01-2021| INV100001|       477|      Germany|Water Bottle - 30...|       4.99|     4.99|            1|  0.3992|          1.8663|
# |01-01-2021| INV100002|       358|       Canada|Mountain-200 Blac...|  2049.0982|2049.0982|            1|163.9279|         1105.81|
# |04-01-2021| INV100003|       485|       Canada|Fender Set - Moun...|      21.98|    21.98|            1|  1.7584|          8.2205|
# |04-01-2021| INV100004|       484|        India|Bike Wash - Disso...|       7.95|     7.95|            1|   0.636|          2.9733|
# ...

# %%
df.write.option("path", "CountriesPart1").partitionBy("Country").save()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("readparquetfile").getOrCreate()

# Use parquet reader instead of csv
df2 = spark.read.parquet("CountriesPart1/Country=France/part-00000-cafac694-4228-47cb-bfd2-aa2b4d5b246b.c000.snappy.parquet")

df2.show()
# Out:
# +----------+----------+----------+--------------------+-----------+---------+-------------+--------+----------------+
# | OrderDate|InvoiceNum|ProductKey|  EnglishProductName|SalesAmount|UnitPrice|OrderQuantity|  TaxAmt|TotalProductCost|
# +----------+----------+----------+--------------------+-----------+---------+-------------+--------+----------------+
# |06-01-2021| INV100005|       580|Road-350-W Yellow...|    1700.99|  1700.99|            1|136.0792|         1082.51|
# |15-01-2021| INV100013|       477|Water Bottle - 30...|       4.99|     4.99|            1|  0.3992|          1.8663|
# |18-01-2021| INV100015|       225|        AWC Logo Cap|       8.99|     8.99|            1|  0.7192|          6.9223|
# |24-01-2021| INV100018|       530|   Touring Tire Tube|       4.99|     4.99|            1|  0.3992|          1.8663|
# |27-01-2021| INV100021|       477|Water Bottle - 30...|       4.99|     4.99|            1|  0.3992|          1.8663|
# ...

# %%
from pyspark.sql.functions import *

# %%
from pyspark.sql.functions import to_date, year, col

# Convert OrderDate string to DateType using the correct format
df = df.withColumn("OrderDate", to_date(col("OrderDate"), "dd-MM-yyyy"))

# Now extract the year
dfnew = df.withColumn("Year", year(col("OrderDate")))

dfnew.show()
# Out:
# +----------+----------+----------+--------------------+-----------+---------+-------------+--------+----------------+----+
# | OrderDate|InvoiceNum|ProductKey|  EnglishProductName|SalesAmount|UnitPrice|OrderQuantity|  TaxAmt|TotalProductCost|Year|
# +----------+----------+----------+--------------------+-----------+---------+-------------+--------+----------------+----+
# |2021-01-06| INV100005|       580|Road-350-W Yellow...|    1700.99|  1700.99|            1|136.0792|         1082.51|2021|
# |2021-01-15| INV100013|       477|Water Bottle - 30...|       4.99|     4.99|            1|  0.3992|          1.8663|2021|
# |2021-01-18| INV100015|       225|        AWC Logo Cap|       8.99|     8.99|            1|  0.7192|          6.9223|2021|
# |2021-01-24| INV100018|       530|   Touring Tire Tube|       4.99|     4.99|            1|  0.3992|          1.8663|2021|
# |2021-01-27| INV100021|       477|Water Bottle - 30...|       4.99|     4.99|            1|  0.3992|          1.8663|2021|
# ...

# %%
from pyspark.sql.functions import to_date, year, col

# Convert OrderDate string to DateType using the correct format
df3 = df3.withColumn("OrderDate", to_date(col("OrderDate"), "dd-MM-yyyy"))

# Now extract the year
dfnew = df3.withColumn("Year", year(col("OrderDate")))

dfnew.show()
# Out:
# +----------+----------+----------+-------------+--------------------+-----------+---------+-------------+--------+----------------+----+
# | OrderDate|InvoiceNum|ProductKey|      Country|  EnglishProductName|SalesAmount|UnitPrice|OrderQuantity|  TaxAmt|TotalProductCost|Year|
# +----------+----------+----------+-------------+--------------------+-----------+---------+-------------+--------+----------------+----+
# |2021-01-01| INV100001|       477|      Germany|Water Bottle - 30...|       4.99|     4.99|            1|  0.3992|          1.8663|2021|
# |2021-01-01| INV100002|       358|       Canada|Mountain-200 Blac...|  2049.0982|2049.0982|            1|163.9279|         1105.81|2021|
# |2021-01-04| INV100003|       485|       Canada|Fender Set - Moun...|      21.98|    21.98|            1|  1.7584|          8.2205|2021|
# |2021-01-04| INV100004|       484|        India|Bike Wash - Disso...|       7.95|     7.95|            1|   0.636|          2.9733|2021|
# ...

# %%
dfnew.write.option("path","CountryYearWise").partitionBy("Country","year").save()

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("delta").getOrCreate()
df5 = spark.read.parquet("CountryYearWise")
df5.show()
# Out:
# +----------+----------+----------+--------------------+-----------+---------+-------------+--------+----------------+-------+----+
# | OrderDate|InvoiceNum|ProductKey|  EnglishProductName|SalesAmount|UnitPrice|OrderQuantity|  TaxAmt|TotalProductCost|Country|year|
# +----------+----------+----------+--------------------+-----------+---------+-------------+--------+----------------+-------+----+
# |2021-01-06| INV100005|       580|Road-350-W Yellow...|    1700.99|  1700.99|            1|136.0792|         1082.51| France|2021|
# |2021-01-15| INV100013|       477|Water Bottle - 30...|       4.99|     4.99|            1|  0.3992|          1.8663| France|2021|
# |2021-01-18| INV100015|       225|        AWC Logo Cap|       8.99|     8.99|            1|  0.7192|          6.9223| France|2021|
# |2021-01-24| INV100018|       530|   Touring Tire Tube|       4.99|     4.99|            1|  0.3992|          1.8663| France|2021|
# ...

# %%
# Out:
#   Cell In[36], line 1
#     select * from productorder where Country = 'France'
#              ^
# SyntaxError: invalid syntax
