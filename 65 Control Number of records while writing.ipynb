# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("readcsvFile").getOrCreate()
df = spark.read.csv("Products.csv",header=True,inferSchema=True)
df.show()
df.count()
# Out:
# +----------+----------+----------+-------------+--------------------+-----------+---------+-------------+--------+----------------+
# | OrderDate|InvoiceNum|ProductKey|      Country|  EnglishProductName|SalesAmount|UnitPrice|OrderQuantity|  TaxAmt|TotalProductCost|
# +----------+----------+----------+-------------+--------------------+-----------+---------+-------------+--------+----------------+
# |01-01-2021| INV100001|       477|      Germany|Water Bottle - 30...|       4.99|     4.99|            1|  0.3992|          1.8663|
# |01-01-2021| INV100002|       358|       Canada|Mountain-200 Blac...|  2049.0982|2049.0982|            1|163.9279|         1105.81|
# |04-01-2021| INV100003|       485|       Canada|Fender Set - Moun...|      21.98|    21.98|            1|  1.7584|          8.2205|
# |04-01-2021| INV100004|       484|        India|Bike Wash - Disso...|       7.95|     7.95|            1|   0.636|          2.9733|
# ...

# %%
#df.write.format("csv").option(header,"True").option("Path","ControlNumber").option("maxRecordsPerFile",500)

# %%
from pyspark.sql import SparkSession
spark = SparkSession.builder.appName("readcsvFile").getOrCreate()
df = spark.read.csv("ControlNumber/part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c000.csv",header=True,inferSchema=True)

df.show()
df.count()
# Out:
# +----------+----------+----------+-------------+--------------------+-----------+---------+-------------+--------+----------------+
# | OrderDate|InvoiceNum|ProductKey|      Country|  EnglishProductName|SalesAmount|UnitPrice|OrderQuantity|  TaxAmt|TotalProductCost|
# +----------+----------+----------+-------------+--------------------+-----------+---------+-------------+--------+----------------+
# |01-01-2021| INV100001|       477|      Germany|Water Bottle - 30...|       4.99|     4.99|            1|  0.3992|          1.8663|
# |01-01-2021| INV100002|       358|       Canada|Mountain-200 Blac...|  2049.0982|2049.0982|            1|163.9279|         1105.81|
# |04-01-2021| INV100003|       485|       Canada|Fender Set - Moun...|      21.98|    21.98|            1|  1.7584|          8.2205|
# |04-01-2021| INV100004|       484|        India|Bike Wash - Disso...|       7.95|     7.95|            1|   0.636|          2.9733|
# ...

# %%
ControlNumber/part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c000.csv

# %%
import os

# List files in a directory
os.listdir("ControlNumber")
# Out:
# ['part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c001.csv',
#  'part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c002.csv',
#  '.part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c002.csv.crc',
#  'part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c000.csv',
#  '_SUCCESS',
#  '.part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c001.csv.crc',
#  'part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c003.csv',
#  '._SUCCESS.crc',
#  '.part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c000.csv.crc',
#  '.part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c003.csv.crc']

# %%
import subprocess

print(subprocess.getoutput("ls -lh ControlNumber"))
# Out:
# total 176K
# -rw-r--r-- 1 jovyan users 41K Mar 21 05:34 part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c000.csv
# -rw-r--r-- 1 jovyan users 41K Mar 21 05:34 part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c001.csv
# -rw-r--r-- 1 jovyan users 41K Mar 21 05:34 part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c002.csv
# -rw-r--r-- 1 jovyan users 41K Mar 21 05:34 part-00000-95ffa100-9af4-4dc2-bcec-83fdac0c69f1-c003.csv
# -rw-r--r-- 1 jovyan users   0 Mar 21 05:34 _SUCCESS
